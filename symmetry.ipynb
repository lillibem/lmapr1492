# %%
from pymatgen.ext.matproj import MPRester

from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
from pymatgen import Structure
from pymatgen.core.operations import SymmOp

from jupyter_jsmol.pymatgen import quick_view
from jupyter_jsmol import JsmolView

# %%
# Télécharger le dossier TiSnPd.cif
with MPRester("pBDutDDdaCLFGZOVupy8") as m:

    structure = m.get_structure_by_material_id("mp-961682")

structure.to(filename="TiSnPd.cif")

# %%
#view = quick_view(structure)
#display(view)

# Symétrie pour l'atome Ti
#view.script("draw symop 8 {atomno=1}") 

# Symétrie pour l'atome Sn
#view.script("draw symop 5 {atomno=2}") 

# Symétrie pour l'atome Pd
#view.script("draw symop 7 {atomno=3}")

# %% [markdown]
# # Opération de symétrie sur Ti
# Plan miroir (z, y, x)
#
# Matrice de rotation : $ \begin{pmatrix}
# 0 & 0 & 1\\
# 0 & 1 & 0\\
# 1 & 0 & 0
# \end{pmatrix}$
#
# Coordonée de l'atome avant symétrie : (0.25, 0.25, 0.25)
#
# Coordonée de l'atome après symétrie : (0.25, 0.25, 0.25)

# %% [markdown]
# ![S1-2.jpg](attachment:S1-2.jpg)

# %% [markdown]
# # Opération de symétrie sur Sn
# Axes 4-bar |centre d'inversion en 0 0 0 (-x-y-z, x, y)
#
# Matrice de rotation : $ \begin{pmatrix}
# -1 & -1 & -1\\
# 1 & 0 & 0\\
# 0 & 1 & 0
# \end{pmatrix}$
#
# Coordonée de l'atome avant symétrie : (0.75, 0.75, 0.75)
#
# Coordonée de l'atome après symétrie : (-2.25, 0.75, 0.75)

# %% [markdown]
# ![S2.jpg](attachment:S2.jpg)

# %% [markdown]
# # Opération de symétrie sur Pb
# Axes C2 (y, x, -x-y-z)
#
# Matrice de rotation : $ \begin{pmatrix}
# 0 & 1 & 0\\
# 1 & 0 & 0\\
# -1 & -1 & -1
# \end{pmatrix}$
#
# Coordonée de l'atome avant symétrie : (0.5, 0.5, 0.5)
#
# Coordonée de l'atome après symétrie : (0.5, 0.5, -1.5)

# %% [markdown]
# ![S3.jpg](attachment:S3.jpg)
